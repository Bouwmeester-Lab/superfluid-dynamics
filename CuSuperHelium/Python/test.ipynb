# %%
import numpy as np

# %%
def c3(alpha, h0):
    return np.sqrt(3*alpha/h0**3)

def freq(zeta, c3, R):
    return zeta * c3 / R

free = 3.832
fixed = 2.405

alpha = 2.6e-24
h0 = 15e-9
R = 6e-3


1/(freq(free, c3(alpha, h0), R)/(2*np.pi))*1000
# Out:
# 6.471354716086325
